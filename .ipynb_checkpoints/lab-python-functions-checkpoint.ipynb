# %% [markdown]
# # Lab | Functions

# %% [markdown]
# # Exercise: Managing Customer Orders with Functions
#
# In the previous exercise, you improved the code for managing customer orders by using loops and flow control. Now, let's take it a step further and refactor the code by introducing functions.
#
# Follow the steps below to complete the exercise:
#
# 1. Define a function named `initialize_inventory` that takes `products` as a parameter. Inside the function, implement the code for initializing the inventory dictionary using a loop and user input.
#
# 2. Define a function named `get_customer_orders` that takes no parameters. Inside the function, implement the code for prompting the user to enter the product names using a loop. The function should return the `customer_orders` set.
#
# 3. Define a function named `update_inventory` that takes `customer_orders` and `inventory` as parameters. Inside the function, implement the code for updating the inventory dictionary based on the customer orders.
#
# 4. Define a function named `calculate_order_statistics` that takes `customer_orders` and `products` as parameters. Inside the function, implement the code for calculating the order statistics (total products ordered, and percentage of unique products ordered). The function should return these values.
#
# 5. Define a function named `print_order_statistics` that takes `order_statistics` as a parameter. Inside the function, implement the code for printing the order statistics.
#
# 6. Define a function named `print_updated_inventory` that takes `inventory` as a parameter. Inside the function, implement the code for printing the updated inventory.
#
# 7. Call the functions in the appropriate sequence to execute the program and manage customer orders.
#
# Hints for functions:
#
# - Consider the input parameters required for each function and their return values.
# - Utilize function parameters and return values to transfer data between functions.
# - Test your functions individually to ensure they work correctly.

# %%
products = ["t-shirt", "mug", "hat", "book", "keychain"]
inventory = {
}
customer_orders = set()
counter = []

## 1
def initialize_inventory(products):
    for i in products:
        inventory[i]= int(input(f"Enter the amount of the product {i} available here: "))
    print(f"Current inventory: {inventory}")
    return inventory
## 2
def get_customer_orders():
    wants_to_continue = True
    another_order = ''
    print(" ")

    while wants_to_continue == True:
        order = input("Please enter the name of a product you want to order: ").strip()
        if order in products and inventory[order]>0:
            customer_orders.add(order)
            counter.append(order)
            update_inventory(counter, inventory)
            while another_order != 'yes' and another_order != 'no':
                another_order = input("Dou you want to order another product? Enter 'yes' or 'no': ").strip()
                if another_order == 'yes':
                    wants_to_continue = True
                elif another_order == 'no':
                    wants_to_continue = False
                else:
                    print("Please enter 'yes' or 'no'")
            another_order=''
        elif order in products and inventory[order]<=0:
            print("Product out of stock! Try another product")
        else:
            print("Please make sure you entered your order correctly!")
    return customer_orders
## 3
def update_inventory(customer_orders, inventory):
    inventory[customer_orders[-1]] = inventory[customer_orders[-1]]-1

    
## 4
def calculate_order_statistics(customer_orders, products):
    total_products_ordered = len(counter)
    percentage = len(customer_orders)/len(products)*100 
    return total_products_ordered, percentage
## 5          
def print_order_statistics(calculate_order_statistics):
    total_products_ordered, percentage = calculate_order_statistics(customer_orders, products)
    print(" ")
    print(f"You ordered {customer_orders}")
    print(" ")
    print("Order statistics:")
    print(f"Total products ordered: {total_products_ordered}")
    print(f"Percentage of total products ordered: {percentage}% ")

## 6
def print_updated_inventory(inventory):
    print(" ")
    print("Updated inventory: ")
    print(" ")
    for key, value in inventory.items():
        print(f"{key}: {value}")
## 7
def start_shop():
    initialize_inventory(products)
    get_customer_orders()
    print_order_statistics(calculate_order_statistics)
    print_updated_inventory(inventory)
    
start_shop()
# Out:
# Enter the amount of the product t-shirt available here: 3
# Enter the amount of the product mug available here: 2
# Enter the amount of the product hat available here: 1
# Enter the amount of the product book available here: 3
# Enter the amount of the product keychain available here: 2
# Current inventory: {'t-shirt': 3, 'mug': 2, 'hat': 1, 'book': 3, 'keychain': 2}
#
# Please enter the name of a product you want to order: hat
# Dou you want to order another product? Enter 'yes' or 'no': yes
# Please enter the name of a product you want to order: hat
# Product out of stock! Try another product
# Please enter the name of a product you want to order: book
# Dou you want to order another product? Enter 'yes' or 'no': no
#
# You ordered {'hat', 'book'}
#
# Order statistics:
# Total products ordered: 2
# Percentage of total products ordered: 40.0%
#
# Updated inventory:
#
# t-shirt: 3
# mug: 2
# hat: 0
# book: 2
# keychain: 2
